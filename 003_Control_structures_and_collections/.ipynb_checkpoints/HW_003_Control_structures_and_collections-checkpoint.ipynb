# %% [markdown]
# ## Задание 1

# %%
test_word = input ('Введите слово: ')
letter_half = int (len (test_word)/2)           # Рассчитываем половину количества букв в слове
if (len (test_word)) % 2 == 0:                  # Проверка, является ли число букв четным?
    print (test_word[letter_half - 1] + test_word[letter_half])
else:
    print (test_word[letter_half])
# Out:
# Введите слово: testing
# t

# %% [markdown]
# ## Задание 2

# %%
user_number = int (input ('Введите число: '))
total = 0
while user_number != 0:
    total += user_number
    user_number = int (input ('Введите число: '))
else:
    print ('Результат: ', total)
# Out:
# Введите число: 7
# Введите число: 5
# Введите число: 8
# Введите число: 9
# Введите число: 0
# Результат  29

# %%
boys = ['Peter', 'Alex', 'John', 'Arthur', 'Richard']
girls = ['Kate', 'Liza', 'Kira', 'Emma', 'Trisha']
if len (boys) == len (girls):
    boys.sort()
    girls.sort()
    result = [x + ' и ' + y for (x,y) in zip(boys, girls)]
    print(result)
    print('Идеальные пары: ')
    for pairs in result:
        print(pairs)
else:
    print('''Результат:
    Внимание, кто-то может остаться без пары!''')
# Out:
# ['Alex и Emma', 'Arthur и Kate', 'John и Kira', 'Peter и Liza', 'Richard и Trisha']
# Идеальные пары:
# Alex и Emma
# Arthur и Kate
# John и Kira
# Peter и Liza
# Richard и Trisha

# %%
boys = ['Peter', 'Alex', 'John', 'Arthur', 'Richard']
girls = ['Kate', 'Liza', 'Kira', 'Emma', 'Trisha']
if len (boys) == len (girls):
    boys.sort()
    girls.sort()
    result = [x + ' и ' + y for (x,y) in zip(boys, girls)]
    for el in result:
        print(el)
# Out:
# Alex и Emma
# Arthur и Kate
# John и Kira
# Peter и Liza
# Richard и Trisha
