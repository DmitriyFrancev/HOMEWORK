# %% [markdown]
# ## Задание 1

# %%
test_word = input('Введите слово: ')
letter_half = int(len(test_word)/2)           # Рассчитываем половину количества букв в слове
if (len(test_word)) % 2 == 0:                  # Проверка, является ли число букв четным?
    print(test_word[letter_half - 1] + test_word[letter_half])
else:
    print (test_word[letter_half])
# Out:
# Введите слово: testing
# t

# %% [markdown]
# ## Задание 2

# %%
user_number = int(input('Введите число: '))
total = 0
while user_number != 0:
    total += user_number
    user_number = int(input('Введите число: '))
else:
    print('Результат: ', total)
# Out:
# Введите число: 7
# Введите число: 5
# Введите число: 8
# Введите число: 9
# Введите число: 0
# Результат  29

# %% [markdown]
# ## Задание 3

# %%
boys = ['Peter', 'Alex', 'John', 'Arthur', 'Richard']
girls = ['Kate', 'Liza', 'Kira', 'Emma', 'Trisha']
if len(boys) == len(girls):
    boys.sort()
    girls.sort()
    result = [x + ' и ' + y for (x,y) in zip(boys, girls)]
    print('Результат: ')
    print('Идеальные пары: ')
    for pairs in result:
        print(pairs)
else:
    print('''Результат:
    Внимание, кто-то может остаться без пары!''')
# Out:
# Результат:
# Идеальные пары:
# Alex и Emma
# Arthur и Kate
# John и Kira
# Peter и Liza
# Richard и Trisha

# %% [markdown]
# ## Задание 4

# %%
countries_temperature = [
['Thailand', [75.2, 77, 78.8, 73.4, 68, 75.2, 77]],
['Germany', [57.2, 55.4, 59, 59, 53.6]],
['Russia', [35.6, 37.4, 39.2, 41, 42.8, 39.2, 35.6]],
['Poland', [50, 50, 53.6, 57.2, 55.4, 55.4]]
]
print('Средняя температура в странах: ')
for country, temperature, in countries_temperature:
    result_celcium = (sum(temperature) / len(temperature) - 32) * 5 / 9
    print(country, '-', round(result_celcium, 1), 'C')
# Out:
# Средняя температура в странах:
# Thailand - 23.9 C
# Germany - 13.8 C
# Russia - 3.7 C
# Poland - 12.0 C

# %% [markdown]
# ## Задание 5

# %%
stream = [
'2018-01-01,user1,3',
'2018-01-07,user1,4',
'2018-03-29,user1,1',
'2018-04-04,user1,13',
'2018-01-05,user2,7',
'2018-06-14,user3,4',
'2018-07-02,user3,10',
'2018-03-21,user4,19',
'2018-03-22,user4,4',
'2018-04-22,user4,8',
'2018-05-03,user4,9',
'2018-05-11,user4,11',
]
stream_conv = []
vizit_number = []
user_names = []
unik_user = []                             
for log_view in stream:                    #Разбивка общих пунктов списка stream на отдельные пункты  
    log_view_sp = log_view.split(',')
    stream_conv.append(log_view_sp)
#print(stream_conv)
for any_user_name in stream_conv:          #Создаем отдельный список имен пользователей 
    #print(user_name[1])
    user_names.append(any_user_name[1])
    vizit_number.append(any_user_name[2])
total_vizit_number = sum(vizit_number)
print(vizit_number)
#print(total_vizit_number)
#total_visit = sum(vizit_number)
#print(total_visit)
for user_unic_names in user_names:         #Определяем количество уникальных пользователей
    if user_unic_names not in unik_user:
        unik_user.append(user_unic_names)
number_unic_user =(len(unik_user))
#for total_vizit_number in  
    
    #break
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-91-863b74aeb495> in <module>
#      25     user_names.append(any_user_name[1])
#      26     vizit_number.append(any_user_name[2])
# ---> 27 total_vizit_number = sum(vizit_number)
#      28 print(vizit_number)
#      29 #print(total_vizit_number)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
